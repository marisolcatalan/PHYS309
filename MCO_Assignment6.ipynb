# %% [markdown]
# # Numerically solving the Schrodinger equation
#
# In this assignment you will use [<tt>qmsolve</tt>](https://github.com/quantum-visualizations/qmsolve) to solve the time-independent Schrodinger equation in one dimension and plot the solutions.
#
# ### First, install <tt>qmsolve</tt> in one of two ways:
# <ul>
#     <li>From a <tt>unix</tt> command line, type <tt>pip install qmsolve</tt></li>
#     <li>Put the following commands in a code cell in this notebook and execute:<br />
#         <tt>import sys</tt><br />
#         <tt>!{sys.executable} -m pip install qmsolve</tt></li>
# </ul>

# %%
pip install qmsolve
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting qmsolve
#   Downloading qmsolve-2.0.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from qmsolve) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from qmsolve) (1.10.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from qmsolve) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from qmsolve) (1.22.4)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->qmsolve) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->qmsolve) (1.16.0)
# Building wheels for collected packages: progressbar
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12080 sha256=8e9350b2c88496c0a2153832fd34f7d016f331375b92e21a24721b24772d1c0e
#   Stored in directory: /root/.cache/pip/wheels/d7/d9/89/a3f31c76ff6d51dc3b1575628f59afe59e4ceae3f2748cd7ad
# Successfully built progressbar
# Installing collected packages: progressbar, qmsolve
# Successfully installed progressbar-2.5 qmsolve-2.0.0

# %%
import sys
# !{sys.executable} -m pip install qmsolve
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: qmsolve in /usr/local/lib/python3.9/dist-packages (2.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from qmsolve) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from qmsolve) (3.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from qmsolve) (3.8.0)
# Requirement already satisfied: progressbar in /usr/local/lib/python3.9/dist-packages (from qmsolve) (2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from qmsolve) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->qmsolve) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->qmsolve) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->qmsolve) (1.16.0)

# %% [markdown]
# ### Homework problems:
#
# <ol start=0>
#     <li>Follow the link to the <tt>qmsolve</tt> GitHub page above. Click the link for the <tt>examples</tt> folder, then click on the <tt>eigenstate solver examples</tt> folder. Finally, click on <tt>1D_harmonic_oscillator.py</tt> to see a short code snippet that will calculate wavefunctions for a simple harmonic oscillator (SHO).</li>
#     <li><tt>1D_harmonic_oscillator.py</tt> imports the <tt>Hamiltonian</tt> class from <tt>qmsolve</tt>. In quantum mechanics, what is a Hamiltonian? Please use multiple sources to formulate your answer and cite those sources. For this problem, crowd-sourced references such as Wikipedia and stackexchange are acceptable.</li>
#     <li>Which force law is defined in the function <tt>harmonic_oscillator()</tt>?</li>
#     <li>What are the eigenstates referred to in lines 22 and 23 in <tt>1D_harmonic_oscillator.py</tt>? Again, please use multiple sources to formulate your answer and cite those sources.
#     <li>Code cells 1 and 2 below contain imported code from <tt>1D_harmonic_oscillator.py</tt>, including a visualization of eigenstate 0 of the SHO. In subsequent code cells, plot any five SHO eigenstates of your choice.</li>
# </ol>
#
# Note: you can write your answers to the non-code problems in a markdown cell. From within a new notebook cell, click the box with a double arrow that says "Code" and change to "Markdown". Then you can just type in the cell like a regular text file.

# %% [markdown]
# **Responses**
# 1. A Hamiltonian in quantum mechanics is the sum of the kinetic energy and potential energy operators in Schrodinger's Equation. The operators and equation can be seen below:
#
#   Here, V(x) is the potential energy in the x dimension and the first term is the kinetic energy in the x direction. ([Source](http://hyperphysics.phy-astr.gsu.edu/hbase/quantum/hamil.html))
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. In the function harmonic_oscillator(), the function returns the spring potntial energy, which is also apart of Hooke's force law, which is U(x) = 0.5*k*x^2, where k is the spring constant, x is the displacement from the initial state, and  U(x) is the potential energy.
#
# 3.
# The eigenstates referred to in lines 22 and 23 in 1D_oscillator.py are the finite levels of each energy state. In this case, we have n = 30, meaning that n=0 corresponds to a ground energy level, which is the lowest energy that the harmonic oscillator can experience. Also, the eigenstates can only take on positive integer values, in this code, it can be any integer number from 0 to 29.
# ([Video Source](https://www.youtube.com/watch?v=0o-LoJRtxDc))

# %%
import numpy as np
import matplotlib.pyplot as plt

from qmsolve import Hamiltonian, SingleParticle, init_visualization, Å, eV

# %%
# Harmonic oscillator potential
def harmonic_oscillator(particle):
    k = 100 * eV / Å**2
    return 0.5 * k * particle.x**2

# Define the Hamiltonian
H = Hamiltonian(particles = SingleParticle(), potential = harmonic_oscillator, 
                spatial_ndim = 1, N = 512, extent = 20*Å)

#Diagonalize the Hamiltonian and compute the eigenstates
eigenstates = H.solve(max_states = 30)

# Print out the energies of the eigenstates
print(eigenstates.energies) # the printed energies are expressed in eV

# Visualize the Eigenstates
visualization = init_visualization(eigenstates)
visualization.plot_eigenstate(0)


# Problem 4 Starts Here
visualization.plot_eigenstate(1)
visualization.plot_eigenstate(5)
visualization.plot_eigenstate(10)
visualization.plot_eigenstate(20)
visualization.plot_eigenstate(29)
# Out:
# Computing...
# Took 0.15909528732299805
# [ 13.8243627   41.46350403  69.08346722  96.68423227 124.26577906
#  151.82808744 179.37113718 206.89490796 234.39937942 261.8845311
#  289.35034249 316.79679298 344.22386192 371.63152856 399.01977209
#  426.38857162 453.73790619 481.06775475 508.3780962  535.66890934
#  562.9401729  590.19186555 617.42396585 644.63645231 671.82930335
#  699.00249732 726.15601246 753.28982697 780.40391895 807.49826642]

# %% [markdown]
# <ol start=5>
#     <li>What is on the x-axis of your plots?</li>
#     <li>Are your plots showing wave functions ψ(x) or probability functions
#     ψ*(x)ψ(x)? How do you know?
# </ol>

# %% [markdown]
# **Responses**
#
# 5.  The x-axis on the plots above is the displacement from the equilibrium position 0 and it is measured in angstroms. As the energy levels increase, the displacement will also increase.
#
# 6. The functions are showing the wave functions ψ(x) because the graph goes to energy levels less than zero. If this were the probability functions ψ*(x)ψ(x), then it would be impossible to have a negative probability for finding a particle in that area.

# %% [markdown]
# ### New potential: infinite square well
#
# Below I define the infinite square well potential and plot the two lowest-energy eigenstates (compare to Figure 6.3 in your textbook).

# %%
# 8 angstrom-wide infinite square well
def infinite_square_well(particle):
    potential = np.zeros_like(particle.x)
    out_of_bounds = np.abs(particle.x) > 4*Å
    potential[out_of_bounds] = np.inf
    return potential

# Define the Hamiltonian of the infinite square well
H_sw = Hamiltonian(particles = SingleParticle(), potential = infinite_square_well, 
                   spatial_ndim = 1, N = 512, extent = 10*Å)

# Diagonalize the Hamiltonian and compute the eigenstates
eigenstates_sw = H_sw.solve(max_states = 30)

print(eigenstates_sw.energies)

# Visualize the infinite square well eigenstates
visualization_sw = init_visualization(eigenstates_sw)
visualization_sw.plot_eigenstate(0)
visualization_sw.plot_eigenstate(1)
# Out:
# Computing...
# Took 0.0918877124786377
# [  0.58926935   2.35704264   5.30321556   9.4276143   14.7299955
#   21.21004635  28.8673845   37.70155819  47.71204619  58.89825789
#   71.2595333   84.79514311  99.50428872 115.3861023  132.43964681
#  150.6639161  170.05783494 190.6202591  212.34997539 235.24570176
#  259.30608737 284.52971266 310.91508944 338.46066097 367.16480207
#  397.0258192  428.04195057 460.21136622 493.53216816 528.00239048]

# %% [markdown]
# <ol start=7>
#     <li>Plot any three infinite square well eigenstates of your choice.</li>
#     <li>What property do the infinite square well eigenstates have that's different than the SHO eigenstates? (Hint: think about the properties of valid wave functions we discussed in class on 4/17)</li>
#     <li>What is the relationship between the number of extrema (maxima plus minima) in each eigenstate plot and the quantum number of the eigenstate?</li>
# </ol>

# %% [markdown]
# Responses

# %%
#Problem 7
visualization_sw.plot_eigenstate(5)
visualization_sw.plot_eigenstate(10)
visualization_sw.plot_eigenstate(15)

# %% [markdown]
# 8. The infinite square well eigenstates do not converge to zero when x approaches infinity unlike SHO eigenstates. Comparing the graphs, the SHO eigenstates fall to zero, however the graphs above do not fade and continue to be sinusoidal waves. This means that the infinite square well eigenstates would not be a good wave function. The second derivative would not exist on the ends since there is a sharp corner.
#
# 9. The number of extrema in each eigenplot is always one more than the quantum number. This means if the quantum number is 5, there will be 6 total number of extrema in the eigenstate plot.

# %% [markdown]
# ### Now it's your turn to define a potential
#
# <ol start=10>
#     <li>Write a function that defines a <em>finite square-well</em> potential (textbook section 5.4). You can choose the width of the well in Angstroms and the potential at the walls in eV. Calculate the finite square-well Hamiltonian and plot any five eigenstates you choose.</li>
#     <li>Based on your plots, do you think a particle can get out of the finite square-well potential no matter its quantum number n?
# </ol>

# %% [markdown]
# **Responses**

# %%
def finite_square_well(particle):
    potential = np.zeros_like(particle.x)
    out_of_bounds = np.abs(particle.x) > 4*Å
    return potential

#Note: The potential will be finite at the bounds, the function will extend at the bounds of 4 Angstroms

H_sw = Hamiltonian(particles = SingleParticle(), potential = finite_square_well, 
                   spatial_ndim = 1, N = 512, extent = 10*Å)

# Diagonalize the Hamiltonian and compute the eigenstates
eigenstates_fin_sw = H_sw.solve(max_states = 30)

print(eigenstates_sw.energies)

# Visualize the finite square well eigenstates
visualization_fin_sw = init_visualization(eigenstates_fin_sw)

visualization_fin_sw.plot_eigenstate(0)
visualization_fin_sw.plot_eigenstate(1)
visualization_fin_sw.plot_eigenstate(10)
visualization_fin_sw.plot_eigenstate(20)
visualization_fin_sw.plot_eigenstate(25)
# Out:
# Computing...
# Took 0.019276857376098633
# [  0.58926935   2.35704264   5.30321556   9.4276143   14.7299955
#   21.21004635  28.8673845   37.70155819  47.71204619  58.89825789
#   71.2595333   84.79514311  99.50428872 115.3861023  132.43964681
#  150.6639161  170.05783494 190.6202591  212.34997539 235.24570176
#  259.30608737 284.52971266 310.91508944 338.46066097 367.16480207
#  397.0258192  428.04195057 460.21136622 493.53216816 528.00239048]

# %% [markdown]
# 11. Based on my plots there does seem to be a chance such that the particle can escape the finite square well potential since the function extends beyond the bounds. This means that there is a probability that the particle will be outside the bounds regardless of the value of the quantum number.
