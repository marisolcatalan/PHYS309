# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants

plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

# %% [markdown]
# Recall that in PHYS 207, you were often asked to plot displacement as a function of time. For example, for a baseball thrown directly upward you would plot $y(t)$, and for a block on a horizontal spring you would plot $x(t)$. Here we will examine how the displacement and time axes "scissor together" at relativistic speeds.
#
# Imagine that frame $K^{\prime}$ is moving in the $+x$ direction at speed $v$ relative to frame $K$. You are at rest in frame $K$. Let's figure out how the set of $(t^{\prime},x^{\prime})$ axes would look to you when the frames' origins $O$ and $O^{\prime}$ coincide.
#
# <ol>
#     <li>Use the fact that $x^{\prime} = 0$ on the $t^{\prime}$ axis to define a line $x(t)$ in frame $K$ that follows the $t^{\prime}$ axis. Write a function that computes points on the line. $v$ will be one of your function inputs.</li>
# </ol>

# %%
def followtp(v, start_time, stop_time):
    tprime = np.arange(start_time, stop_time)
    xprime = v*tprime 
    return tprime, xprime   

followtp(5, 0, 10)
plt.plot(followtp(5, 0, 10)[0], followtp(5, 0, 10)[1])

# %% [markdown]
# <ol start=2>
#     <li>Use the fact that $t^{\prime} = 0$ on the $x^{\prime}$ axis to define a line $x(t)$ that traces the $x^{\prime}$ axis in frame $K$. Write a second function that computes points on this line.</li>
# </ol>

# %%
def followxp(v, start_pos, end_pos): 
    numx = (np.arange(start_pos, end_pos))
    tprime = np.zeros(len(numx), dtype=int)
    xprime = numx*v   
    return tprime, xprime

followtp(5, 0, 10)
plt.plot(followxp(5, 0, 10)[0], followxp(5, 0, 10)[1])

# %% [markdown]
# <ol start=3>
#     <li>The code below creates a figure with centered $(ct,x)$ axes that have range $(-10^{10}, 10^{10})$. We are using $ct$ instead of just $t$ on our horizontal axis so that both axes have the same units. Use your functions from problems 1 and 2 to overplot the $t^{\prime}$ and $x^{\prime}$ axes <strong>as a function of $ct$</strong> for $v = 0.2c$. Make your $t^{\prime}$ and $x^{\prime}$ axes red, and label them in red.</li>
# </ol>

# %%
# Set up an array of independent variables t that spans -100 to 100 seconds
t = np.linspace(0, 200, num=201, endpoint=True) - 100

# Make a figure
fig, ax = plt.subplots(figsize=(7,7))

# YOUR CODE HERE: Use ax.plot() to plot the t' and x' axes below

#The following is assigning variables to the arrays from each function
tp_axis = followtp(0.2*constants.c, -100, 100)
xp_axis = followxp(0.2*constants.c,-1000, 1000)

tp_ax_t = tp_axis[0]*constants.c
tp_ax_x = tp_axis[1]

xp_ax_t = xp_axis[0]
xp_ax_x = xp_axis[1] 

#Plotting the axis, which is two lines, one is the x' line and the other is the t' line
ax.plot(tp_ax_t, tp_ax_x, color = "red")
ax.plot(xp_ax_t, xp_ax_x, color = "red")


# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10]) 
ax.set_ylim([-1e10, 1e10])

# Labelling the axes
ax.text(1.025e10, 2e9, "ct'", color="red")
ax.text(0, 1.025e10, "x'", color = "red")
# Out:
# Text(0, 10250000000.0, "x'")

# %% [markdown]
# <ol start=4>
#     <li>Make a figure that plots $t^{\prime}$ and $x^{\prime}$ axes for $v = 0.25c$, $v = 0.5c$, and $v = 0.75c$. Use different colors for each pair of axes. Make a legend that shows which value of $v$ corresponds to each color.</li>
# </ol>

# %%
fig, ax = plt.subplots(figsize=(7,7))

#The following is assigning variables to the arrays from each function

# For v = 0.25c
tp_axis1 = followtp(0.25*constants.c, -100, 100)
xp_axis1 = followxp(0.25*constants.c,-1000, 1000)

ax.plot(tp_axis1[0]*constants.c, tp_axis1[1], color = "red")
ax.plot(xp_axis1[0], xp_axis1[1], color = "red")

# For v = 0.5c
tp_axis2 = followtp(0.5*constants.c, -100, 100)
xp_axis2 = followxp(0.5*constants.c,-1000, 1000)

ax.plot(tp_axis2[0]*constants.c, tp_axis2[1], color = "blue")
#ax.plot(xp_axis2[0],xp_axis2[1], color = "blue")

# For v = 0.75c
tp_axis3 = followtp(0.75*constants.c, -100, 100)
xp_axis3 = followxp(0.75*constants.c,-1000, 1000)

ax.plot(tp_axis3[0]*constants.c, tp_axis3[1], color = "green")
#ax.plot(xp_axis3[0], xp_axis3[1], color = "green")


# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10]) 
ax.set_ylim([-1e10, 1e10])

# Labelling the axes
ax.text(1.025e10, 2e9, "ct'", color="red")
ax.text(0, 1.025e10, "x'", color = "red")

ax.text(1.025e10, 5e9, "ct'", color="blue")
#ax.text(0, 1.025e10, "x'", color = "blue")

ax.text(1.025e10, 7.5e9, "ct'", color="green")
#ax.text(0, 1.025e10, "x'", color = "red")

ax.legend(["x' axis", "v = 0.25c", "v = 0.5c", "v = 0.75c"] )

# %% [markdown]
# <ol start=5>
#     <li>Connect your graph from problem 4 with the discussion of world lines in Chapter 2 of your textbook. What kind of world line do your $(t^{\prime}, x^{\prime})$ axes approach as $v \rightarrow c$? Create a similar plot to problem 4, but this time plot $(t^{\prime}, x^{\prime})$ axes for $v = 0.5, 0.75, 0.875, 0.9375$. To illustrate the concept of taking a limit as $v \rightarrow c$, make each set of $(t^{\prime}, x^{\prime})$ axes a successively darker shade of gray. Plot the limiting world line in black. Add a legend to show which value of $v$ corresponds to which shade of gray. You may find it helpful to specify line colors like this: <tt>color='0.7'</tt>.</li>
# </ol>

# %%
fig, ax = plt.subplots(figsize=(7,7))

#The following is assigning variables to the arrays from each function
# For v = 0.5c
tp_axis1 = followtp(0.25*constants.c, -100, 100)
xp_axis1 = followxp(0.25*constants.c,-1000, 1000)

ax.plot(tp_axis1[0]*constants.c, tp_axis1[1], color = "0.8")
ax.plot(xp_axis1[0], xp_axis1[1], color = "0.8")

# For v = 0.75c
tp_axis2 = followtp(0.5*constants.c, -100, 100)
xp_axis2 = followxp(0.5*constants.c,-1000, 1000)

ax.plot(tp_axis2[0]*constants.c, tp_axis2[1], color = "0.6")

# For v = 0.875c
tp_axis3 = followtp(0.75*constants.c, -100, 100)
xp_axis3 = followxp(0.75*constants.c,-1000, 1000)

ax.plot(tp_axis3[0]*constants.c, tp_axis3[1], color = "0.4")

#For v = 0.9375c
tp_axis4 = followtp(0.9375*constants.c, -100, 100)
xp_axis4 = followxp(0.9375*constants.c,-1000, 1000)

ax.plot(tp_axis4[0]*constants.c, tp_axis4[1], color = "0.2")

#For v = c
tp_axis5 = followtp(constants.c, -100, 100)
xp_axis5 = followxp(constants.c,-1000, 1000)

ax.plot(tp_axis5[0]*constants.c, tp_axis5[1], color = "0")

# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10]) 
ax.set_ylim([-1e10, 1e10])

# Labelling the lines/axes
ax.text(1.025e10, 2e9, "ct'", color="0.8")
ax.text(0, 1.025e10, "x'", color = "0.2")
ax.text(1.025e10, 5e9, "ct'", color="0.6")
ax.text(1.025e10, 7.5e9, "ct'", color="0.4")
ax.text(1.025e10, 9.25e9, "ct'", color="0.2")
ax.text(1.025e10, 1.025e10, "ct'", color="0")

ax.legend(["x' axis", "v = 0.5c", "v = 0.75c", "v = 0.875c", "v = 0.9375c", "v = c"], loc = "lower right")

# %% [markdown]
# I expect that the world line as v approaches c will be a one to one ratio, much like a 45 degree angle. This can be shown by the limiting world line in black. As the velocity approaches the speed of light, the ct' axis gets closer and closer to the limiting world line where v = c.
